# %%
import numpy as np
import derpy
from time import sleep
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from tqdm import tqdm
from scipy.optimize import minimize

from katsu.mueller import(
    linear_retarder,
    linear_polarizer
)

# %%
cam = derpy.CRED2(set_temperature=-41, fps=10, tint=50, temp_tolerance=1) # TODO: add units to docstring (also add docstring)
# Out:
# Updating...
# Sensor Temperature: -42.48C
# Motherboard Temperature: 44.75C
# Frontend Temperature: 49.0C
# Powerboard Temperature: 54.75C
# Peltier Temperature: 21.5C
# Heatsink Temperature: 51.94C
# ***********************
# Sensor Temperature: -42.48C
# Motherboard Temperature: 44.75C
# Frontend Temperature: 49.0C
# Powerboard Temperature: 54.75C
# Peltier Temperature: 21.5C
# Heatsink Temperature: 51.94C
# ***********************
# Sensor Temperature: -42.48C
# Motherboard Temperature: 44.75C
# Frontend Temperature: 49.0C
# Powerboard Temperature: 54.75C
# Peltier Temperature: 21.5C
# Heatsink Temperature: 51.94C
# ***********************
# Sensor Temperature: -42.56C
# Motherboard Temperature: 44.75C
# Frontend Temperature: 49.25C
# Powerboard Temperature: 54.75C
# Peltier Temperature: 21.19C
# Heatsink Temperature: 52.16C
# ***********************
# Sensor Temperature: -41.85C
# Motherboard Temperature: 44.75C
# Frontend Temperature: 49.0C
# Powerboard Temperature: 54.5C
# Peltier Temperature: 21.24C
# Heatsink Temperature: 52.11C
# ***********************
# Final Sensor Temperature -41.72C
# Current camera tint: 50.002251ms

# %%
cam.close()

# %% [markdown]
# # Take a Dark

# %%
from pathlib import Path
from astropy.io import fits

def save_fits(data, pth, tint=50, fps=10, temp=-40, wavelength=0, overwrite=False):

    hdu = fits.PrimaryHDU(data)

    # set up fits headers
    hdu.header['TINT'] = tint
    hdu.header['FPS'] = fps
    hdu.header['SET TEMP'] = temp
    hdu.header['WVL'] = wavelength

    hdu.writeto(pth, overwrite=overwrite)

N_IMS = 100
dark = cam.take_median_image(N_IMS)

# %%
plt.title(f"Dark frame, open cap, {N_IMS}imgs")
plt.imshow(dark, vmax=2**14)
plt.colorbar()

# %%
from numpy.fft import fft2, fftshift
# Out:
# array([[4.2841e+04, 1.0000e+00, 0.0000e+00, ..., 1.2260e+03, 1.3030e+03,
#         1.5810e+03],
#        [1.3350e+03, 1.3820e+03, 1.2750e+03, ..., 1.2090e+03, 3.4720e+03,
#         2.4980e+03],
#        [1.3560e+03, 1.2320e+03, 1.3140e+03, ..., 4.1500e+03, 1.2500e+03,
#         1.4530e+03],
#        ...,
#        [1.4630e+03, 1.3350e+03, 1.3900e+03, ..., 1.3320e+03, 1.3320e+03,
#         1.4060e+03],
#        [1.4630e+03, 1.2290e+03, 1.2850e+03, ..., 1.3010e+03, 1.2550e+03,
#         1.2550e+03],
#        [1.5230e+03, 1.3530e+03, 1.3560e+03, ..., 1.3610e+03, 1.3600e+03,
#         1.6610e+03]], shape=(512, 640))

# %% [markdown]
# # Take a Bright

# %%
# im_stack = cam.take_many_images(N_IMS)
im_stack_dark_subtract = [i - 1.015*dark for i in im_stack]
im_median = np.median(im_stack_dark_subtract, axis=0)

# %%
WVL = 1500
DATA_DIR = Path.home() / "Desktop/derp_data/brightness_control"

plt.figure(figsize=[10,5])
plt.title(f"{WVL}nm image, median of {N_IMS} frames, dark subtracted")
vlim = 100
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# three wavelengths, 20nm
# save_fits(im_median, pth=DATA_DIR / f"{WVL}_no_qwp_nm", wavelength=WVL)

# %%
WVL = 1600
DATA_DIR = Path.home() / "Desktop/derp_data/brightness_control"

plt.figure(figsize=[10,5])
plt.title(f"{WVL}nm image, median of {N_IMS} frames, dark subtracted")
vlim = 100
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# three wavelengths, 20nm
save_fits(im_median, pth=DATA_DIR / f"{WVL}_no_qwp_nm", wavelength=WVL)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 12
#       9 plt.show()
#      11 # three wavelengths, 20nm
# ---> 12 save_fits(im_median, pth=DATA_DIR / f"{WVL}_no_qwp_nm", wavelength=WVL)
#
# Cell In[7], line 14, in save_fits(data, pth, tint, fps, temp, wavelength, overwrite)
#      11 hdu.header['SET TEMP'] = temp
#      12 hdu.header['WVL'] = wavelength
# ---> 14 hdu.writeto(pth, overwrite=overwrite)
#
# File c:\Users\Brewster\anaconda3\envs\drrp\lib\site-packages\astropy\io\fits\hdu\base.py:412, in _BaseHDU.writeto(self, name, output_verify, overwrite, checksum)
#     409 from .hdulist import HDUList
#     411 hdulist = HDUList([self])
# --> 412 hdulist.writeto(name, output_verify, overwrite=overwrite, checksum=checksum)
#
# File c:\Users\Brewster\anaconda3\envs\drrp\lib\site-packages\astropy\io\fits\hdu\hdulist.py:1032, in HDUList.writeto(self, fileobj, output_verify, overwrite, checksum)
#    1028 mode = FILE_MODES[fileobj_mode(fileobj)] if isfile(fileobj) else "ostream"
#    1030 # This can accept an open file object that's open to write only, or in
#    1031 # append/update modes but only if the file doesn't exist.
# -> 1032 fileobj = _File(fileobj, mode=mode, overwrite=overwrite)
#    1033 hdulist = self.fromfile(fileobj)
#    1034 try:
#
# File c:\Users\Brewster\anaconda3\envs\drrp\lib\site-packages\astropy\io\fits\file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File c:\Users\Brewster\anaconda3\envs\drrp\lib\site-packages\astropy\io\fits\file.py:640, in _File._open_filename(self, filename, mode, overwrite)
#     638 """Open a FITS file from a filename string."""
#     639 if mode == "ostream":
# --> 640     self._overwrite_existing(overwrite, None, True)
#     642 if os.path.exists(self.name):
#     643     with open(self.name, "rb") as f:
#
# File c:\Users\Brewster\anaconda3\envs\drrp\lib\site-packages\astropy\io\fits\file.py:523, in _File._overwrite_existing(self, overwrite, fileobj, closed)
#     521         os.remove(self.name)
#     522 else:
# --> 523     raise OSError(NOT_OVERWRITING_MSG.format(self.name))
#
# OSError: File C:\Users\Brewster\Desktop\derp_data\brightness_control\1600_no_qwp_nm already exists. If you mean to replace it then use the argument "overwrite=True".

# %%
WVL = 1700
DATA_DIR = Path.home() / "Desktop/derp_data/brightness_control"

plt.figure(figsize=[10,5])
plt.title(f"{WVL}nm image, median of {N_IMS} frames, dark subtracted")
vlim = 100
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# three wavelengths, 20nm
save_fits(im_median, pth=DATA_DIR / f"{WVL}_no_qwp_nm", wavelength=WVL)

# %%
WVL = 1400
DATA_DIR = Path.home() / "Desktop/derp_data/brightness_control"

plt.figure(figsize=[10,5])
plt.title(f"{WVL}nm image, median of {N_IMS} frames, dark subtracted")
vlim = 100
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# three wavelengths, 20nm
save_fits(im_median, pth=DATA_DIR / f"{WVL}_no_qwp_nm", wavelength=WVL)

# %%
plt.figure(figsize=[10,5])
plt.title(f"1495, 1500, 1505")
vlim = 200
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=[10,5])
plt.title(f"1490, 1500, 1510")
vlim = 200
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=[10,5])
plt.title(f"1480, 1500, 1520")
vlim = 200
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# %%
wvl = 1500
bw = 0.05
# Looks like diminishing returns after a 5% bw
print(wvl * np.linspace(1-bw/2, 1+bw/2, 3))
# Out:
# [1462.5 1500.  1537.5]

# %%
plt.figure(figsize=[10,5])
plt.title(f"1462.5, 1500, 1537.5")
vlim = 200
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# %%
wvl = 1500
bw = 0.10
print(wvl * np.linspace(1-bw/2, 1+bw/2, 3))
# Out:
# [1425. 1500. 1575.]

# %%
plt.figure(figsize=[10,5])
plt.title(f"1425, 1500, 1575")
vlim = 200
plt.imshow(im_median, vmax=vlim, vmin=-vlim, cmap="RdBu_r")
plt.colorbar()
plt.show()

# %%
cam.close()
