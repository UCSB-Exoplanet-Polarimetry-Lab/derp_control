# %% [markdown]
# CRED Frame Grabber Test

# %%
# imports 
import sys
sys.path.append("C:\Program Files\FirstLightImaging\FliSdk\Python\demo")
import FliSdk_V2 as sdk
import derpy as dp
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# We want to take a ton of frames and figure out how often the frame wrapping occurs... we'll check this using the tint, framerate values from the throughput measurements

# %%
cam = dp.CRED2(set_temperature = -40, fps = 100, tint = 0.1, temp_tolerance = 0.5, conversion_gain = 'lo')
# Out:
# Updating...
# Sensor Temperature: 16.14C
# Motherboard Temperature: 35.0C
# Frontend Temperature: 33.0C
# Powerboard Temperature: 31.25C
# Peltier Temperature: 23.55C
# Heatsink Temperature: 28.61C
# ***********************
# Sensor Temperature: 16.14C
# Motherboard Temperature: 35.0C
# Frontend Temperature: 33.0C
# Powerboard Temperature: 31.25C
# Peltier Temperature: 23.55C
# Heatsink Temperature: 28.61C
# ***********************
# Sensor Temperature: 16.14C
# Motherboard Temperature: 35.0C
# Frontend Temperature: 33.0C
# Powerboard Temperature: 31.25C
# Peltier Temperature: 23.55C
# Heatsink Temperature: 28.61C
# ***********************
# Sensor Temperature: 19.02C
# Motherboard Temperature: 36.25C
# Frontend Temperature: 33.75C
# Powerboard Temperature: 32.0C
# Peltier Temperature: 20.55C
# Heatsink Temperature: 29.29C
# ***********************
# Sensor Temperature: 17.85C
# Motherboard Temperature: 36.75C
# Frontend Temperature: 34.0C
# Powerboard Temperature: 33.0C
# ...

# %%
cam.close()

# %%
# test image
im = cam.take_median_image(10)
plt.imshow(im, vmin=0, vmax=14000)
plt.colorbar()
plt.show()

# %%
cam.tint = 0.15
cam.fps = 500
sdk.FliCredTwo.EnableBadPixel(cam.context, True)
# Out:
# Current camera tint: 0.150159ms
# True

# %%
sp_usb = 'C:\\Users\\Brewster\\Desktop\\FrameGrabberTest\\9_17_2025_Matrox_usb'
cam.take_many_images(1000, save_path = sp_usb)
# Out:
# array([[[2.3071e+04, 2.0000e+00, 0.0000e+00, ..., 5.2230e+03,
#          5.1570e+03, 5.4320e+03],
#         [3.1040e+03, 3.1740e+03, 4.0870e+03, ..., 5.3480e+03,
#          9.0200e+03, 6.6850e+03],
#         [3.1980e+03, 3.3990e+03, 3.2870e+03, ..., 1.0153e+04,
#          4.0170e+03, 4.6080e+03],
#         ...,
#         [4.3280e+03, 3.7640e+03, 3.3700e+03, ..., 3.7140e+03,
#          3.7140e+03, 3.8440e+03],
#         [4.1730e+03, 3.5140e+03, 3.6090e+03, ..., 3.2880e+03,
#          3.1970e+03, 3.1970e+03],
#         [4.0660e+03, 4.0480e+03, 4.2180e+03, ..., 3.4310e+03,
#          4.1030e+03, 4.7820e+03]],
#
#        [[2.3071e+04, 2.0000e+00, 0.0000e+00, ..., 5.2230e+03,
#          5.1570e+03, 5.4320e+03],
#         [3.1040e+03, 3.1740e+03, 4.0870e+03, ..., 5.3480e+03,
#          9.0200e+03, 6.6850e+03],
#         [3.1980e+03, 3.3990e+03, 3.2870e+03, ..., 1.0153e+04,
#          4.0170e+03, 4.6080e+03],
#         ...,
#         [4.3280e+03, 3.7640e+03, 3.3700e+03, ..., 3.7140e+03,
# ...

# %% [markdown]
# Disconnect the camera and reconnect with the frame grabbers

# %%
sp_fg = 'C:\\Users\\Brewster\\Desktop\\FrameGrabberTest\\9_17_2025_Matrox_fg'
cam.take_many_images(1000, save_path = sp_fg)
# Out:
# array([[[0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         ...,
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         ...,
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
# ...
